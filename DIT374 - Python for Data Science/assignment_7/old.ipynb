# %%
#DIT374 Assignment 7
#Erik Rosvall 960523
#Christoffer Wikner 931012

#Question 1

import math
import sys

class Graph:
    def __init__(self, gdict = {}):
        self.gdict = gdict
        self.colour = {}
        self.distance = {}
        self.predecessor = {}
        self.finish = {}     
        
    def get_vertices(self):
        vertices = set()
        for u in self.gdict:
            vertices.add(u)
            for v in self.gdict[u]:
                vertices.add(v)
        return vertices
        #return list(self.gdict.keys())
    
    def get_edges(self):
        edgename = []
        for vertex in self.gdict:
            for next_vertex in self.gdict[vertex]:
                if {next_vertex, vertex} not in edgename:
                    edgename.append({vertex, next_vertex})
        return edgename    
    
    def add_vertex(self, vertex):
        if vertex not in self.gdict:
            self.gdict[vertex] = []
            
    def add_edge(self, edge):
        edge = set(edge)
        (vertex1, vertex2) = tuple(edge)
        if vertex1 in self.gdict:
            self.gdict[vertex1].append(vertex2)
        else:
            self.gdict[vertex1] = [vertex2]
            
    # BFS and DFS are implemented using the pseudo-codes from the Book
    def BFS(self, s):
        vertices = self.get_vertices()
        vertices.remove(s)
        for u in vertices:
            self.colour[u] = "White"
            self.distance[u] = 0
            self.predecessor[u] = None
        self.colour[s] = "Gray"
        self.distance[s] = 0
        self.predecessor[s] = None
        queue = []
        queue.append(s)
        while queue:
            u = queue.pop(0)
            #print(self.gdict[u])
            for v in self.gdict[u]:
                if self.colour[v] == "White":
                    self.colour[v] = "Gray"
                    self.distance[v] = self.distance[u] + 1
                    self.predecessor[v] = u
                    queue.append(v)
            self.colour[u] = "Black"    
            
    def print_path(self, s, v):
        if v in self.gdict.keys():
            if v == s:
                print(s)
            elif self.predecessor[v] == None:
                print("There is no path from", s, "to", v, "exists.")
            else:
                self.print_path(s, self.predecessor[v])
                print(v)
        else: 
            print("Node with key", v, "is not in the graph.")       
            
    def DFS(self):
        for u in self.gdict:
            self.colour[u] = "White"
            self.predecessor[u] = None
            self.distance[u] = 0    # Added to initialise self.distance
            self.finish[u] = -1     # Added to initialise self.finish
        global time 
        time = 0
        for u in self.gdict:
            if self.colour[u] == "White":
                self._DFS_visit(u)        
                
    def _DFS_visit(self, u):
        global time
        time += 1      # white vertex u has just been discovered
        self.distance[u] = time
        self.colour[u] = "Gray"
        for v in self.gdict[u]:  # explore edge(u,v)
            if self.colour[v] == "White":
                self.predecessor[v] = u
                self._DFS_visit(v)
        self.colour[u] = "Black"   # blacken u; it is finished
        time += 1
        self.finish[u] = time

    # ----- New functionality -----

    def initilise_single_source(self, s):
        for v in self.get_vertices():
            self.distance[v] = math.inf # close to infinity
            self.predecessor = None
        self.distance[s] = 0

    def get_weight(self, u, v):
        return self.gdict[u][v]

    def relax(self, v, u):
        if self.distance[v] > self.distance[u] + self.get_weight(u,v):
            self.distance[v] = self.distance[u] + self.get_weight(u, v)
            self.predecessor[v] = u

    # DAG
    def dag_shortest_paths(self, s):
        self.topological_sort()  # O(V+E)
        self.initialise_single_source(s)  # O(V)
        for u in self.finish.keys():      # O(V+E)
            for v in self.gdict[u].keys():
                self.relax(u, v)
    
    def extract_min(self, candidates):
        min = 999999
        for cu in candidates:
            if self.distance[cu] < min:
                min = self.distance[cu]
                u = cu  
        return u

    def topological_sort(self):
        self.DFS()
        #return self.finish()
        
        
        
    def dijkstra(self, source, dest):
        assert source in self.get_vertices()
        dist = {vertex: math.inf for vertex in self.get_vertices()}
        previous = {vertex: None for vertex in self.get_vertices()}
        dist[source] = 0 # Tror den kommer ge fel
        q = self.get_vertices()
        neighbours = {vertex: set() for vertex in self.get_vertices()}
        for start, end, cost in self.edges:
            neighbours[start].add((end, cost))
            neighbours[end].add((start, cost))
 
        #pp(neighbours)
 
        while q:
            # pp(q)
            u = min(q, key=lambda vertex: dist[vertex])
            q.remove(u)
            if dist[u] == inf or u == dest:
                break
            for v, cost in neighbours[u]:
                alt = dist[u] + cost
                if alt < dist[v]:                                  # Relax (u,v,a)
                    dist[v] = alt
                    previous[v] = u
        #pp(previous)
        s, u = deque(), dest
        while previous[u]:
            s.appendleft(u)
            u = previous[u]
        s.appendleft(u)
        return s

# %%
adjacency5 = {"s" : {"t": 10, "y": 5},
              "t" : {"x": 1, "y": 2},
              "x" : {"z": 4},
              "y" : {"t": 3, "x": 9, "z": 2},
              "z" : {"x": 6, "s": 7}
              }

gg = Graph(adjacency5)

# %%
gg.dijkstra('s', 'Z')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-f0b87110e2f7> in <module>
# ----> 1 gg.dijkstra('s', 'Z')
#
# <ipython-input-54-9449de035df6> in dijkstra(self, source, dest)
#     151         q = self.get_vertices()
#     152         neighbours = {vertex: set() for vertex in self.get_vertices()}
# --> 153         for start, end, cost in self.edges:
#     154             neighbours[start].add((end, cost))
#     155             neighbours[end].add((start, cost))
#
# AttributeError: 'Graph' object has no attribute 'edges'

# %% [markdown]
# **KeyError:** A KeyError generally means the key doesn't exist.
#
# So, are you sure the path key exists?

# %%
def dijkstra(self, s):
    self.initialise_single_source(s)
    processed = []
    non_processed = []
    
    non_processed = self.get_vertices()
    
    while non_processed:
        u = self.extract_min(non_processed)
        non_processed.remove(u)
        processed = processed + [u]
        for v in self.gdict[u]:
                self.relax(u, v)

# %%
def dijkstra(self, src):
 
        #dist = [sys.maxsize] * self.get_vertices()
        
        #dist[src] = 0
        #sptSet = [False] * self.get_vertices() # vad gör denna?
        dist = self.get_vertices()
        S = []
        dist[len(src)] = 0
        Q = self.get_vertices()

        #neighbours = {vertex: set() for vertex in self.vertices}
        #neighbours = self.get_vertices()
        neighbours = {d: dict() for d in self.get_edges()}
        E = self.get_edges()
        for start, end, cost in E:
            neighbours[start].add((end, cost))
            neighbours[end].add((start, cost))
        
        # x = u
        while Q:
            u = self.extract_min(Q)
            Q.remove(u)
            if dist[u] == math.inf:
                break
            #S = S + [u]
            #Q[u] = True

            for v, cost in neighbours[u]:
                temp = dist[u] + cost
                if temp < dist[v]:                                  # Relax (u,v,a)
                    dist[v] = temp
                    #previous[v] = u
                    self.predecessor[v] = u
            
        s, u = deque(), dest
        while self.predecessor[u]:
            s.appendleft(u)
            u = previous[u]
            s.appendleft(u)
        return s

        """
        for y in self.gdict[u]:
            if self.gdict[u][y] > 0 and Q[y] == False and \
            dist[y] > dist[u] + self.gdict[u][y]:
                    dist[y] = dist[u] + self.gdict[u][y]
                    self.relax(u,y)
        """

# %%
"""
***** REFERENCE *****
"""
def dijkstra(self, s):
        """solves the single-source shortest-paths problem on a 
        weighted, directed graph G = (V, E) whose all edge weights
        are non-negative.
        
        Parameter:
        s: a string representing the source vertex from which shortest-paths will be 
        seached
        """
        self.initialise_single_source(s)
        # S is a list for vertices that have been processed
        S = []
        # Q is a list for vertices that have not been processed
        Q = self.get_vertices() 
        while Q:
            u = self.extract_min(Q)
            Q.remove(u)
            S = S + [u] 
            for v in self.gdict[u]:
                self.relax(u, v)

# %%
# Dijkstra Algorithm
    def dijkstra(self, src):
 
        #dist = [sys.maxsize] * self.get_vertices()
        
        #dist[src] = 0
        #sptSet = [False] * self.get_vertices() # vad gör denna?
        dist = self.get_vertices()
        S = []
        #dist[len(src)] = 0
        Q = self.get_vertices()

        #neighbours = {vertex: set() for vertex in self.vertices}
        #neighbours = self.get_vertices()
        #neighbours = {d: dict() for d in self.get_edges()}
        neighbours = {vertex: set() for vertex in self.get_vertices()}
        E = self.get_edges()
        for start, end, cost in E:
            neighbours[start].add((end, cost))
            neighbours[end].add((start, cost))
        
        # x = u
        while Q:
            u = self.extract_min(Q)
            Q.remove(u)
            if dist[u] == math.inf:
                break
            #S = S + [u]
            #Q[u] = True

            for v, cost in neighbours[u]:
                temp = dist[u] + cost
                if temp < dist[v]:                                  # Relax (u,v,a)
                    dist[v] = temp
                    #previous[v] = u
                    self.predecessor[v] = u
            
        s, u = deque(), dest
        while self.predecessor[u]:
            s.appendleft(u)
            u = previous[u]
            s.appendleft(u)
        return s
