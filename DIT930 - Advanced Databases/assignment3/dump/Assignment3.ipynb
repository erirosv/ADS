# %%
import pandas as pd

# %%
# reading the CSV files
courses = pd.read_csv('Courses.csv')
coursePlannings = pd.read_csv('Course_Plannings.csv')
courseInstances = pd.read_csv('Course_Instances.csv')
programmeCourses = pd.read_csv('Programme_Courses.csv')
programmes = pd.read_csv('Programmes.csv')
assignedHours = pd.read_csv('Assigned_Hours.csv')
reportedHours = pd.read_csv('Reported_Hours.csv')
registrations = pd.read_csv('Registrations.csv')
seniorTeachers = pd.read_csv('Senior_Teachers.csv')
teachingAssistants = pd.read_csv('Teaching_Assistants.csv')
students = pd.read_csv('Students.csv')

# %%
courses.head()
# Out:
#   Course name  Course code  Credits         Level Department Division Owned By
# 0         C-1         1001      7.5  Second Cycle         D6     D6-5     P-52
# 1         C-2         1002      7.5  Second Cycle         D2     D2-2     P-12
# 2         C-3         1003      7.5   First Cycle         D1     D1-4     P-02
# 3         C-4         1004      7.5  Second Cycle         D5     D5-1     P-43
# 4         C-5         1005      7.5  Second Cycle         D6     D6-2     P-52

# %%
coursePlannings.head()
# Out:
#   Course  Planned number of Students  Senior Hours  Assistant Hours
# 0    I-1                         100           260              700
# 1    I-2                         150           240              700
# 2    I-3                         100           260              560
# 3    I-4                         150           280              360
# 4    I-5                         150           260              700

# %%
courseInstances.head()
# Out:
#    Course code  Study period Academic year Instance_id       Examiner
# 0         1763           1.0     2010-2011         I-1  19581118-0029
# 1         1556           2.0     2010-2011         I-2  19680307-0062
# 2         1516           4.0     2010-2011         I-3  19691216-0147
# 3         1293           3.0     2010-2011         I-4  19650728-0047
# 4         1741           3.0     2010-2011         I-5  19671119-0137

# %%
programmeCourses.head()
# Out:
#    Programme code  Study Year Academic Year  Course Course Type
# 0           10001         1.0     2010-2011    1763  compulsory
# 1           10001         1.0     2010-2011    1556  compulsory
# 2           10001         1.0     2010-2011    1516  compulsory
# 3           10001         1.0     2010-2011    1293  compulsory
# 4           10001         1.0     2010-2011    1741    elective

# %%
programmes.head()
# Out:
#   Programme name  Programme code Department name       Director
# 0           P-01           10001              D1  19591012-0095
# 1           P-02           10002              D1  19600503-0067
# 2           P-03           10003              D1  19551112-0017
# 3           P-11           10011              D2  19630224-0041
# 4           P-12           10012              D2  19650814-0090

# %%
assignedHours.head()
# Out:
#    Course code  Study Period Academic Year     Teacher Id  Hours  \
# 0         1763           1.0     2010-2011  19680307-0062  240.0
# 1         1763           1.0     2010-2011  19770310-0188  100.0
# 2         1763           1.0     2010-2011  19901025-0328  120.0
# 3         1763           1.0     2010-2011  19920428-0326  140.0
# 4         1556           2.0     2010-2011  19670913-0054  240.0
#
#   Course Instance
# 0             I-1
# 1             I-1
# 2             I-1
# 3             I-1
# 4             I-2

# %%
reportedHours.head()
# Out:
#   Course code     Teacher Id  Hours
# 0         I-1  19680307-0062  229.0
# 1         I-1  19770310-0188  115.0
# 2         I-1  19901025-0328  120.0
# 3         I-1  19920428-0326  126.0
# 4         I-2  19670913-0054  238.0

# %%
registrations.head()
# Out:
#   Course Instance     Student id     Status  Grade
# 0           I-910  19870405-0000  completed    3.0
# 1           I-912  19870405-0000  completed    3.0
# 2           I-914  19870405-0000  completed    3.0
# 3           I-913  19870405-0000  completed    5.0
# 4          I-3574  19870405-0000  completed    5.0

# %%
seniorTeachers.head()
# Out:
#   Teacher name     Teacher id Department name Division name
# 0    Teacher 1  19550711-0001              D1          D1-3
# 1    Teacher 2  19640131-0002              D3          D3-5
# 2    Teacher 3  19590109-0003              D7          D7-3
# 3    Teacher 4  19641017-0004              D1          D1-3
# 4    Teacher 5  19630316-0005              D5          D5-2

# %%
teachingAssistants.head()
# Out:
#   Teacher name     Teacher id Department name Division name
# 0       TA 151  19780321-0151              D1          D1-2
# 1       TA 152  19751107-0152              D7          D7-2
# 2       TA 153  19760106-0153              D7          D7-0
# 3       TA 154  19780210-0154              D6          D6-5
# 4       TA 155  19750330-0155              D1          D1-5

# %%
students.head()
# Out:
#   Student name     Student id  Programme  Year  Graduated
# 0    Student 1  19980118-0000      10012  2021      False
# 1    Student 2  19980516-0001      10022  2019      False
# 2    Student 3  19950813-0002      10074  2019      False
# 3    Student 4  19960415-0003      10031  2020      False
# 4    Student 5  19980711-0004      10061  2020      False

# %%
print("INSERT DATA {")

for row in students.iterrows():
    currentRow = row[1]
    studentID = currentRow["Student id"]
    studentName = currentRow["Student name"]
    print (":" + studentID + " rdf:type " + ":Individual ;");
    print (":hasID '" + studentID + "' ;");
    print (":hasName '" + studentName + "' .");
    
print("}")
# Out:
# INSERT DATA {
# :19980118-0000 rdf:type :Individual ;
# :hasID '19980118-0000' ;
# :hasName 'Student 1' .
# :19980516-0001 rdf:type :Individual ;
# :hasID '19980516-0001' ;
# :hasName 'Student 2' .
# :19950813-0002 rdf:type :Individual ;
# :hasID '19950813-0002' ;
# :hasName 'Student 3' .
# :19960415-0003 rdf:type :Individual ;
# :hasID '19960415-0003' ;
# :hasName 'Student 4' .
# :19980711-0004 rdf:type :Individual ;
# :hasID '19980711-0004' ;
# :hasName 'Student 5' .
# :19960331-0005 rdf:type :Individual ;
# :hasID '19960331-0005' ;
# :hasName 'Student 6' .
# :19961002-0006 rdf:type :Individual ;
# :hasID '19961002-0006' ;
# :hasName 'Student 7' .
# :19961022-0007 rdf:type :Individual ;
# :hasID '19961022-0007' ;
# :hasName 'Student 8' .
# :19960302-0008 rdf:type :Individual ;
# :hasID '19960302-0008' ;
# :hasName 'Student 9' .
# :19991110-0009 rdf:type :Individual ;
# :hasID '19991110-0009' ;
# :hasName 'Student 10' .
# :19950922-0010 rdf:type :Individual ;
# ...

# %%
print("INSERT DATA {")

for row in teachingAssistants.iterrows():
    currentRow = row[1]
    taID = currentRow["Teacher id"]
    taName = currentRow["Teacher name"]
    print (":" + taID + " rdf:type " + ":Individual ;");
    print (":hasID '" + taID + "' ;");
    print (":hasName '" + taName + "' .");
    
print("}")
# Out:
# INSERT DATA {
# :19780321-0151 rdf:type :Individual ;
# :hasID '19780321-0151' ;
# :hasName 'TA 151' .
# :19751107-0152 rdf:type :Individual ;
# :hasID '19751107-0152' ;
# :hasName 'TA 152' .
# :19760106-0153 rdf:type :Individual ;
# :hasID '19760106-0153' ;
# :hasName 'TA 153' .
# :19780210-0154 rdf:type :Individual ;
# :hasID '19780210-0154' ;
# :hasName 'TA 154' .
# :19750330-0155 rdf:type :Individual ;
# :hasID '19750330-0155' ;
# :hasName 'TA 155' .
# :19750319-0156 rdf:type :Individual ;
# :hasID '19750319-0156' ;
# :hasName 'TA 156' .
# :19771213-0157 rdf:type :Individual ;
# :hasID '19771213-0157' ;
# :hasName 'TA 157' .
# :19790714-0158 rdf:type :Individual ;
# :hasID '19790714-0158' ;
# :hasName 'TA 158' .
# :19781121-0159 rdf:type :Individual ;
# :hasID '19781121-0159' ;
# :hasName 'TA 159' .
# :19790106-0160 rdf:type :Individual ;
# :hasID '19790106-0160' ;
# :hasName 'TA 160' .
# :19750630-0161 rdf:type :Individual ;
# :hasID '19750630-0161' ;
# :hasName 'TA 161' .
# ...

# %%
print("INSERT DATA {")
 
for row in seniorTeachers.iterrows():
    currentRow = row[1]
    taID = currentRow["Teacher id"]
    taName = currentRow["Teacher name"]
    print (":" + taID + " rdf:type " + ":Individual ;");
    print (":hasID '" + taID + "' ;");
    print (":hasName '" + taName + "' .");
    
print("}")
# Out:
# INSERT DATA {
# :19550711-0001 rdf:type :Individual ;
# :hasID '19550711-0001' ;
# :hasName 'Teacher 1' .
# :19640131-0002 rdf:type :Individual ;
# :hasID '19640131-0002' ;
# :hasName 'Teacher 2' .
# :19590109-0003 rdf:type :Individual ;
# :hasID '19590109-0003' ;
# :hasName 'Teacher 3' .
# :19641017-0004 rdf:type :Individual ;
# :hasID '19641017-0004' ;
# :hasName 'Teacher 4' .
# :19630316-0005 rdf:type :Individual ;
# :hasID '19630316-0005' ;
# :hasName 'Teacher 5' .
# :19580826-0006 rdf:type :Individual ;
# :hasID '19580826-0006' ;
# :hasName 'Teacher 6' .
# :19580131-0007 rdf:type :Individual ;
# :hasID '19580131-0007' ;
# :hasName 'Teacher 7' .
# :19550720-0008 rdf:type :Individual ;
# :hasID '19550720-0008' ;
# :hasName 'Teacher 8' .
# :19561112-0009 rdf:type :Individual ;
# :hasID '19561112-0009' ;
# :hasName 'Teacher 9' .
# :19610502-0010 rdf:type :Individual ;
# :hasID '19610502-0010' ;
# :hasName 'Teacher 10' .
# :19580607-0011 rdf:type :Individual ;
# ...
